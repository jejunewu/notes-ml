# %%
import json
import torch
from torch.utils.data import Dataset
import transformers
from transformers import BertTokenizer

# %% [markdown]
# ## model embedding

# %%
class ModelEmbedding:
    def __init__(self, pretraind_model: str = 'bert-base-uncased'):
        tokenizer = BertTokenizer.from_pretrained(
            pretrained_model_name_or_path=pretraind_model,
            cache_dir=None,
            force_download=False,
        )

# %%
JSON_PATH = r'D:\\DataModel\\LSTMCRF\\labeled_data.json'
file = open(JSON_PATH, "r")
raw_data= json.load(file)[:1000]
raw_data
# Out:
# [[['in',
#    'this',
#    'work',
#    ',',
#    'an',
#    'effective',
#    'outlier',
#    'detection',
#    'method',
#    'based',
#    'on',
#    'multi-dimensional',
#    'clustering',
#    'and',
#    'local',
#    'density',
#    '(',
#    'odbmcld',
#    ')',
#    'is',
#    'proposed',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'O',
#    'M',
#    'O',
#    'O',
#    'O',
#    'O']],
#  [['the',
#    'data',
#    'driven',
#    'model',
#    'is',
#    'built',
#    'based',
#    'on',
#    'artificial',
#    'neural',
#    'networks',
#    '(',
#    'anns',
#    ')',
#    ',',
#    'while',
#    'the',
#    'developed',
#    'multi-criteria',
#    'decision',
#    'analysis',
#    'model',
#    'uses',
#    'technique',
#    'for',
#    'order',
#    'of',
#    'preference',
#    'by',
#    'similarity',
#    'to',
#    'ideal',
# ...
