# %%
import torch
from torch import nn

import DataLoader_WF

# %%
corpus, vocab = DataLoader_WF.load_corpus()

# %%
vocab.token_freqs
# Out:
# [('的', 1501),
#  ('我', 1424),
#  ('你', 638),
#  ('在', 636),
#  ('一', 585),
#  ('不', 548),
#  ('是', 467),
#  (' ', 466),
#  ('这', 418),
#  ('有', 370),
#  ('着', 269),
#  ('那', 254),
#  ('爱', 234),
#  ('就', 229),
#  ('们', 223),
#  ('到', 211),
#  ('生', 204),
#  ('了', 192),
#  ('天', 192),
#  ('个', 187),
#  ('像', 186),
#  ('无', 186),
#  ('想', 179),
#  ('人', 178),
#  ('心', 176),
#  ('要', 174),
#  ('为', 169),
#  ('没', 154),
#  ('么', 154),
#  ('来', 151),
#  ('去', 151),
#  ('会', 149),
#  ('可', 148),
#  ('如', 143),
#  ('觉', 143),
#  ('上', 140),
#  ('再', 140),
#  ('中', 136),
#  ('样', 135),
#  ('道', 131),
#  ('命', 131),
#  ('自', 130),
#  ('里', 129),
#  ('感', 127),
#  ('地', 126),
#  ('唱', 125),
#  ('也', 123),
#  ('得', 121),
#  ('让', 115),
#  ('知', 115),
#  ('还', 115),
#  ('都', 112),
#  ('见', 109),
#  ('只', 108),
#  ('时', 105),
#  ('梦', 104),
#  ('空', 99),
#  ('然', 99),
#  ('汪', 98),
#  ('峰', 98),
#  ('能', 97),
#  ('远', 96),
#  ('演', 95),
#  ('：', 92),
#  ('和', 90),
#  ('碎', 89),
#  ('已', 89),
# ...
