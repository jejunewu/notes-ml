# %%
from sklearn.neighbors import KNeighborsRegressor as KNR

from sklearn.model_selection import cross_val_score as CVS , train_test_split as TTS
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_boston

from ML_Algorithm_test.EvaluationModel import EvaluationModel as EM

import numpy as np

# %%
# 1 准备数据
# 读取波士顿地区房价信息
boston = load_boston()
# 查看数据描述
# print(boston.DESCR)   # 共506条波士顿地区房价信息，每条13项数值特征描述和目标房价
# 查看数据的差异情况
# print("最大房价：", np.max(boston.target))   # 50
# print("最小房价：",np.min(boston.target))    # 5
# print("平均房价：", np.mean(boston.target))   # 22.532806324110677

x = boston.data
y = boston.target

print('all:',x.shape,'--->',y.shape)
# Out:
# all: (506, 13) ---> (506,)

# %%
# 2 分割训练数据和测试数据
# 随机采样25%作为测试 75%作为训练
x_train, x_test, y_train, y_test = TTS(x, y, test_size=0.25, random_state=33)

print('train:',x_train.shape,'--->',y_train.shape)
print('test:',x_test.shape,'--->',y_test.shape)
# Out:
# train: (379, 13) ---> (379,)
# test: (127, 13) ---> (127,)

# %%
# # 3 训练数据和测试数据进行标准化处理
# ss_x = StandardScaler()
# x_train = ss_x.fit_transform(x_train)
# x_test = ss_x.transform(x_test)
# 
# ss_y = StandardScaler()
# y_train = ss_y.fit_transform(y_train.reshape(-1, 1))
# y_test = ss_y.transform(y_test.reshape(-1, 1))

# %%
# 4.1 RFR模型进行学习和预测
# 配置RFR
K = 3

regr = KNR(n_neighbors=K)

regr.fit(x_train, y_train)

regr_y_predict = regr.predict(x_test)

EM.modelEvaluate(regr, x_test, y_test)
# Out:
# K =  1
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.40638386244153246
# R^2值为： 0.40638386244153246
# 均方误差(MSE)为: 46.029763779527556
# 平均绝对误差(MAE)为: 4.363779527559054
# ===================================================
# K =  2
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.553277652517159
# R^2值为： 0.553277652517159
# 均方误差(MSE)为: 34.63942913385827
# 平均绝对误差(MAE)为: 4.014566929133858
# ===================================================
# K =  3
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.6544081712016646
# R^2值为： 0.6544081712016646
# 均方误差(MSE)为: 26.79763779527559
# 平均绝对误差(MAE)为: 3.7317585301837264
# ===================================================
# K =  4
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.6586241747120891
# R^2值为： 0.6586241747120891
# 均方误差(MSE)为: 26.47072342519685
# 平均绝对误差(MAE)为: 3.7068897637795275
# ===================================================
# K =  5
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.6406342556368118
# R^2值为： 0.6406342556368118
# 均方误差(MSE)为: 27.865685039370078
# 平均绝对误差(MAE)为: 3.771811023622048
# ===================================================
# K =  6
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.6101972011326617
# R^2值为： 0.6101972011326617
# 均方误差(MSE)为: 30.225813648293958
# 平均绝对误差(MAE)为: 3.9367454068241474
# ===================================================
# K =  7
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.6076168699298647
# R^2值为： 0.6076168699298647
# 均方误差(MSE)为: 30.42589587015908
# 平均绝对误差(MAE)为: 3.875928008998876
# ===================================================
# K =  8
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.5952630600692974
# R^2值为： 0.5952630600692974
# 均方误差(MSE)为: 31.383826279527554
# 平均绝对误差(MAE)为: 3.898818897637795
# ===================================================
# K =  9
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.5764274890036509
# R^2值为： 0.5764274890036509
# 均方误差(MSE)为: 32.84436084378343
# 平均绝对误差(MAE)为: 4.003149606299212
# ===================================================
# K =  10
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.5657158104249205
# R^2值为： 0.5657158104249205
# 均方误差(MSE)为: 33.67495826771654
# 平均绝对误差(MAE)为: 4.07031496062992
# ===================================================
# K =  11
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.5614337573263093
# R^2值为： 0.5614337573263093
# 均方误差(MSE)为: 34.00699420836859
# 平均绝对误差(MAE)为: 4.063278453829636
# ===================================================
# K =  12
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.5432559836730082
# R^2值为： 0.5432559836730082
# 均方误差(MSE)为: 35.41652230971129
# 平均绝对误差(MAE)为: 4.120866141732284
# ===================================================
# K =  13
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.5297711898725184
# R^2值为： 0.5297711898725184
# 均方误差(MSE)为: 36.46215067791084
# 平均绝对误差(MAE)为: 4.179769836462748
# ===================================================
# K =  14
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.5310002938071399
# R^2值为： 0.5310002938071399
# 均方误差(MSE)为: 36.366844367668314
# 平均绝对误差(MAE)为: 4.2396512935883
# ===================================================
# K =  15
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.5227024603453476
# R^2值为： 0.5227024603453476
# 均方误差(MSE)为: 37.010269116360455
# 平均绝对误差(MAE)为: 4.267086614173227
# ===================================================
# K =  16
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.5200125714991459
# R^2值为： 0.5200125714991459
# 均方误差(MSE)为: 37.21884657972441
# 平均绝对误差(MAE)为: 4.291732283464567
# ===================================================
# K =  17
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.509648761478128
# R^2值为： 0.509648761478128
# 均方误差(MSE)为: 38.02246982535488
# 平均绝对误差(MAE)为: 4.301204261232054
# ===================================================
# K =  18
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.5106467898494236
# R^2值为： 0.5106467898494236
# 均方误差(MSE)为: 37.945081413434416
# 平均绝对误差(MAE)为: 4.285345581802275
# ===================================================
# K =  19
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.505734655695043
# R^2值为： 0.505734655695043
# 均方误差(MSE)为: 38.325974654830205
# 平均绝对误差(MAE)为: 4.295814338997098
# ===================================================
# K =  20
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.5035655174692307
# R^2值为： 0.5035655174692307
# 均方误差(MSE)为: 38.49417244094488
# 平均绝对误差(MAE)为: 4.310787401574803
# ===================================================
# K =  21
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.4994424756161829
# R^2值为： 0.4994424756161828
# 均方误差(MSE)为: 38.81387844376596
# 平均绝对误差(MAE)为: 4.338695163104613
# ===================================================
# K =  22
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.4908195063741726
# R^2值为： 0.4908195063741726
# 均方误差(MSE)为: 39.482514641764816
# 平均绝对误差(MAE)为: 4.392591267000715
# ===================================================
# K =  23
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.4850194892082288
# R^2值为： 0.4850194892082288
# 均方误差(MSE)为: 39.93225548129733
# 平均绝对误差(MAE)为: 4.479698733310509
# ===================================================
# K =  24
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.4764633091120309
# R^2值为： 0.47646330911203083
# 均方误差(MSE)为: 40.59571276246718
# 平均绝对误差(MAE)为: 4.534186351706038
# ===================================================
# K =  25
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.46854191270659407
# R^2值为： 0.46854191270659407
# 均方误差(MSE)为: 41.20994809448819
# 平均绝对误差(MAE)为: 4.577354330708662
# ===================================================
# K =  26
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.4564853618144883
# R^2值为： 0.4564853618144883
# 均方误差(MSE)为: 42.14482865862181
# 平均绝对误差(MAE)为: 4.661205330102966
# ===================================================
# K =  27
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.4526264293167381
# R^2值为： 0.452626429316738
# 均方误差(MSE)为: 42.44405528012702
# 平均绝对误差(MAE)为: 4.6544473607465715
# ===================================================
# K =  28
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.4423389958775689
# R^2值为： 0.442338995877569
# 均方误差(MSE)为: 43.241756186726654
# 平均绝对误差(MAE)为: 4.66681664791901
# ===================================================
# K =  29
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.4328471578406482
# R^2值为： 0.4328471578406482
# 均方误差(MSE)为: 43.97776559588791
# 平均绝对误差(MAE)为: 4.689356502850936
# ===================================================
# K =  30
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.4279517985486505
# R^2值为： 0.4279517985486505
# 均方误差(MSE)为: 44.357358092738416
# 平均绝对误差(MAE)为: 4.7096325459317585
# ===================================================
# K =  31
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.41976625789273303
# R^2值为： 0.41976625789273303
# 均方误差(MSE)为: 44.992075511892956
# 平均绝对误差(MAE)为: 4.748793497586996
# ===================================================
# K =  32
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.41301386853776123
# R^2值为： 0.41301386853776123
# 均方误差(MSE)为: 45.51566452386812
# 平均绝对误差(MAE)为: 4.7913877952755906
# ===================================================
# K =  33
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.4108919990459473
# R^2值为： 0.4108919990459473
# 均方误差(MSE)为: 45.68019703115623
# 平均绝对误差(MAE)为: 4.802600811262229
# ===================================================
# K =  34
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.4061210864435517
# R^2值为： 0.4061210864435517
# 均方误差(MSE)为: 46.05013977059096
# 平均绝对误差(MAE)为: 4.818573413617415
# ===================================================
# K =  35
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.39949376584855234
# R^2值为： 0.39949376584855234
# 均方误差(MSE)为: 46.56403078900852
# 平均绝对误差(MAE)为: 4.847086614173229
# ===================================================
# K =  36
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3897890450633593
# R^2值为： 0.3897890450633593
# 均方误差(MSE)为: 47.31654740206085
# 平均绝对误差(MAE)为: 4.885892388451443
# ===================================================
# K =  37
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3862200974376342
# R^2值为： 0.3862200974376342
# 均方误差(MSE)为: 47.59328822118565
# 平均绝对误差(MAE)为: 4.915067035539475
# ===================================================
# K =  38
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.38146157426107996
# R^2值为： 0.38146157426107996
# 均方误差(MSE)为: 47.962270268501754
# 平均绝对误差(MAE)为: 4.946000828843763
# ===================================================
# K =  39
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3736134784702203
# R^2值为： 0.3736134784702203
# 均方误差(MSE)为: 48.57082177597622
# 平均绝对误差(MAE)为: 5.003815869170199
# ===================================================
# K =  40
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3678788749810361
# R^2值为： 0.3678788749810361
# 均方误差(MSE)为: 49.0154903543307
# 平均绝对误差(MAE)为: 5.029173228346457
# ===================================================
# K =  41
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3671086118556047
# R^2值为： 0.3671086118556047
# 均方误差(MSE)为: 49.07521755423048
# 平均绝对误差(MAE)为: 5.01634338390628
# ===================================================
# K =  42
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.365985397375595
# R^2值为： 0.365985397375595
# 均方误差(MSE)为: 49.162313059081875
# 平均绝对误差(MAE)为: 5.034889388826397
# ===================================================
# K =  43
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3602950946228656
# R^2值为： 0.3602950946228656
# 均方误差(MSE)为: 49.60354650098159
# 平均绝对误差(MAE)为: 5.05387291704816
# ===================================================
# K =  44
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.35537026187414056
# R^2值为： 0.35537026187414056
# 均方误差(MSE)为: 49.98542440782196
# 平均绝对误差(MAE)为: 5.075536864710094
# ===================================================
# K =  45
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.34635560332879356
# R^2值为： 0.34635560332879356
# 均方误差(MSE)为: 50.68443270146786
# 平均绝对误差(MAE)为: 5.126649168853891
# ===================================================
# K =  46
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.33633411502478083
# R^2值为： 0.33633411502478083
# 均方误差(MSE)为: 51.461511878004856
# 平均绝对误差(MAE)为: 5.187144813420062
# ===================================================
# K =  47
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3344068007730253
# R^2值为： 0.3344068007730253
# 均方误差(MSE)为: 51.61095832011491
# 平均绝对误差(MAE)为: 5.222985424694254
# ===================================================
# K =  48
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.32918220662381004
# R^2值为： 0.32918220662381004
# 均方误差(MSE)为: 52.01608011400919
# 平均绝对误差(MAE)为: 5.241387795275591
# ===================================================
# K =  49
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3289221454614045
# R^2值为： 0.3289221454614045
# 均方误差(MSE)为: 52.03624559320756
# 平均绝对误差(MAE)为: 5.248883175317371
# ===================================================
# K =  50
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3268752952564684
# R^2值为： 0.3268752952564684
# 均方误差(MSE)为: 52.194961007874014
# 平均绝对误差(MAE)为: 5.254614173228346
# ===================================================
# K =  51
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3254465973123245
# R^2值为： 0.3254465973123245
# 均方误差(MSE)为: 52.305744096001845
# 平均绝对误差(MAE)为: 5.264335340435387
# ===================================================
# K =  52
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.32120206019461006
# R^2值为： 0.32120206019461006
# 均方误差(MSE)为: 52.634870998928385
# 平均绝对误差(MAE)为: 5.278073894609329
# ===================================================
# K =  53
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.32065797898708026
# R^2值为： 0.32065797898708026
# 均方误差(MSE)为: 52.67705976010742
# 平均绝对误差(MAE)为: 5.283182290892884
# ===================================================
# K =  54
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3175348993787648
# R^2值为： 0.3175348993787648
# 均方误差(MSE)为: 52.919227395958224
# 平均绝对误差(MAE)为: 5.2948964712744235
# ===================================================
# K =  55
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3158171229530877
# R^2值为： 0.3158171229530877
# 均方误差(MSE)为: 53.05242600377432
# 平均绝对误差(MAE)为: 5.310350751610595
# ===================================================
# K =  56
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3102189313412791
# R^2值为： 0.3102189313412791
# 均方误差(MSE)为: 53.486517028563384
# 平均绝对误差(MAE)为: 5.324817210348706
# ===================================================
# K =  57
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31208564818973483
# R^2值为： 0.31208564818973483
# 均方误差(MSE)为: 53.34176938755233
# 平均绝对误差(MAE)为: 5.322682690979415
# ===================================================
# K =  58
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3172497659076976
# R^2值为： 0.3172497659076976
# 均方误差(MSE)为: 52.941337014427894
# 平均绝对误差(MAE)为: 5.3091637252240025
# ===================================================
# K =  59
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31976146167765573
# R^2值为： 0.31976146167765573
# 均方误差(MSE)为: 52.74657687287797
# 平均绝对误差(MAE)为: 5.296209795809422
# ===================================================
# K =  60
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31995693780767853
# R^2值为： 0.31995693780767853
# 均方误差(MSE)为: 52.73141940069991
# 平均绝对误差(MAE)为: 5.300249343832021
# ===================================================
# K =  61
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31725939651917767
# R^2值为： 0.31725939651917767
# 均方误差(MSE)为: 52.9405902443463
# 平均绝对误差(MAE)为: 5.312495159416547
# ===================================================
# K =  62
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3158842468227726
# R^2值为： 0.3158842468227726
# 均方误差(MSE)为: 53.047221132022905
# 平均绝对误差(MAE)为: 5.310782321564643
# ===================================================
# K =  63
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31498225129169566
# R^2值为： 0.31498225129169566
# 均方误差(MSE)为: 53.11716303319228
# 平均绝对误差(MAE)为: 5.32729658792651
# ===================================================
# K =  64
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31424668698624736
# R^2值为： 0.31424668698624736
# 均方误差(MSE)为: 53.17419964167077
# 平均绝对误差(MAE)为: 5.3376230314960615
# ===================================================
# K =  65
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3124073707163866
# R^2值为： 0.3124073707163866
# 均方误差(MSE)为: 53.31682260634581
# 平均绝对误差(MAE)为: 5.33726226529376
# ===================================================
# K =  66
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31224956882209876
# R^2值为： 0.31224956882209876
# 均方误差(MSE)为: 53.329058769513324
# 平均绝对误差(MAE)为: 5.337866857551897
# ===================================================
# K =  67
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3120864393207279
# R^2值为： 0.3120864393207279
# 均方误差(MSE)为: 53.34170804223097
# 平均绝对误差(MAE)为: 5.331672346926784
# ===================================================
# K =  68
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31083146538630635
# R^2值为： 0.31083146538630635
# 均方误差(MSE)为: 53.43902034574832
# 平均绝对误差(MAE)为: 5.347776748494673
# ===================================================
# K =  69
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31065891050035754
# R^2值为： 0.31065891050035754
# 均方误差(MSE)为: 53.45240047498789
# 平均绝对误差(MAE)为: 5.347814675339496
# ===================================================
# K =  70
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3080642638315181
# R^2值为： 0.3080642638315181
# 均方误差(MSE)为: 53.65359273662221
# 平均绝对误差(MAE)为: 5.364949381327336
# ===================================================
# K =  71
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3045514057635338
# R^2值为： 0.3045514057635338
# 均方误差(MSE)为: 53.92598429882835
# 平均绝对误差(MAE)为: 5.382178108018188
# ===================================================
# K =  72
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.30325290779905223
# R^2值为： 0.30325290779905223
# 均方误差(MSE)为: 54.026671511981135
# 平均绝对误差(MAE)为: 5.392771216097988
# ===================================================
# K =  73
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.30646292559159194
# R^2值为： 0.30646292559159194
# 均方误差(MSE)为: 53.777762576778656
# 平均绝对误差(MAE)为: 5.3846079171610395
# ===================================================
# K =  74
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3045208885764408
# R^2值为： 0.3045208885764408
# 均方误差(MSE)为: 53.92835064102194
# 平均绝对误差(MAE)为: 5.393626303468823
# ===================================================
# K =  75
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3060536060195873
# R^2值为： 0.3060536060195873
# 均方误差(MSE)为: 53.809501746281704
# 平均绝对误差(MAE)为: 5.388566929133859
# ===================================================
# K =  76
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3077434463657819
# R^2值为： 0.3077434463657819
# 均方误差(MSE)为: 53.678469338233676
# 平均绝对误差(MAE)为: 5.381620389556568
# ===================================================
# K =  77
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3103223100578395
# R^2值为： 0.3103223100578395
# 均方误差(MSE)为: 53.47850090905107
# 平均绝对误差(MAE)为: 5.367982411289498
# ===================================================
# K =  78
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3124961055406764
# R^2值为： 0.3124961055406764
# 均方误差(MSE)为: 53.30994199319759
# 平均绝对误差(MAE)为: 5.354128810821725
# ===================================================
# K =  79
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3134455977155971
# R^2值为： 0.3134455977155971
# 均方误差(MSE)为: 53.23631714077719
# 平均绝对误差(MAE)为: 5.3508621548888655
# ===================================================
# K =  80
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31059191381445617
# R^2值为： 0.31059191381445617
# 均方误差(MSE)为: 53.45759548474408
# 平均绝对误差(MAE)为: 5.363120078740158
# ===================================================
# K =  81
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3104687146868831
# R^2值为： 0.3104687146868831
# 均方误差(MSE)为: 53.467148504585076
# 平均绝对误差(MAE)为: 5.3612229026927185
# ===================================================
# K =  82
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31297903145718875
# R^2值为： 0.31297903145718875
# 均方误差(MSE)为: 53.27249529245341
# 平均绝对误差(MAE)为: 5.35374495870943
# ===================================================
# K =  83
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3123920162915954
# R^2值为： 0.3123920162915954
# 均方误差(MSE)为: 53.31801320832138
# 平均绝对误差(MAE)为: 5.361379375770801
# ===================================================
# K =  84
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3129843910001421
# R^2值为： 0.3129843910001421
# 均方误差(MSE)为: 53.272079706554536
# 平均绝对误差(MAE)为: 5.357114735658042
# ===================================================
# K =  85
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31143222015468663
# R^2值为： 0.31143222015468663
# 均方误差(MSE)为: 53.39243704329346
# 平均绝对误差(MAE)为: 5.368059286706809
# ===================================================
# K =  86
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3124929904353414
# R^2值为： 0.3124929904353414
# 均方误差(MSE)为: 53.31018354249797
# 平均绝对误差(MAE)为: 5.359897454678631
# ===================================================
# K =  87
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31309850210026646
# R^2值为： 0.31309850210026646
# 均方误差(MSE)为: 53.263231384126925
# 平均绝对误差(MAE)为: 5.362430989229795
# ===================================================
# K =  88
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.31371144513483384
# R^2值为： 0.31371144513483384
# 均方误差(MSE)为: 53.21570298773346
# 平均绝对误差(MAE)为: 5.361435218324982
# ===================================================
# K =  89
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3140545637330333
# R^2值为： 0.3140545637330333
# 均方误差(MSE)为: 53.18909712744057
# 平均绝对误差(MAE)为: 5.36309829248872
# ===================================================
# K =  90
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3144054810277199
# R^2值为： 0.3144054810277199
# 均方误差(MSE)为: 53.16188654612616
# 平均绝对误差(MAE)为: 5.373359580052494
# ===================================================
# K =  91
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3121603491557666
# R^2值为： 0.3121603491557666
# 均方误差(MSE)为: 53.33597697794115
# 平均绝对误差(MAE)为: 5.3890109890109885
# ===================================================
# K =  92
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3110905651239848
# R^2值为： 0.3110905651239848
# 均方误差(MSE)为: 53.4189294166679
# 平均绝对误差(MAE)为: 5.399075659020884
# ===================================================
# K =  93
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3089673290851521
# R^2值为： 0.3089673290851521
# 均方误差(MSE)为: 53.58356788778093
# 平均绝对误差(MAE)为: 5.419447972229276
# ===================================================
# K =  94
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3079789920998304
# R^2值为： 0.3079789920998304
# 均方误差(MSE)为: 53.660204817086864
# 平均绝对误差(MAE)为: 5.426017758418494
# ===================================================
# K =  95
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.30858591782765776
# R^2值为： 0.30858591782765776
# 均方误差(MSE)为: 53.61314301044779
# 平均绝对误差(MAE)为: 5.425122254455033
# ===================================================
# K =  96
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3082666075830106
# R^2值为： 0.3082666075830106
# 均方误差(MSE)为: 53.63790274018482
# 平均绝对误差(MAE)为: 5.434251968503938
# ===================================================
# K =  97
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3064644774022568
# R^2值为： 0.3064644774022568
# 均方误差(MSE)为: 53.77764224737079
# 平均绝对误差(MAE)为: 5.445230944070134
# ===================================================
# K =  98
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.3058934988476758
# R^2值为： 0.3058934988476758
# 均方误差(MSE)为: 53.821916663660474
# 平均绝对误差(MAE)为: 5.450899887514063
# ===================================================
# K =  99
# =============== KNeighborsRegressor ===============
# 默认评估值为： 0.306218959348986
# R^2值为： 0.306218959348986
# 均方误差(MSE)为: 53.79668003505989
# 平均绝对误差(MAE)为: 5.454410244174024
# ===================================================

# %%
# 5 模型评估
# 线性核函数 模型评估
# print("线性核函数支持向量机的默认评估值为：", regr.score(x_test, y_test))
# print("线性核函数支持向量机的R_squared值为：", r2_score(y_test, regr_y_predict))
# print("线性核函数支持向量机的均方误差为:", mean_squared_error(ss_y.inverse_transform(y_test),
#                                               ss_y.inverse_transform(regr_y_predict)))
# print("线性核函数支持向量机的平均绝对误差为:", mean_absolute_error(ss_y.inverse_transform(y_test),
#                                                  ss_y.inverse_transform(regr_y_predict)))
