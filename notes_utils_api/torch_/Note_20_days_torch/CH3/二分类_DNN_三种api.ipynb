# %%
import numpy as np
import pandas as pd
from plotly import graph_objects as go
import torch
from torch import nn

# %%
# 准备数据

#正负样本数量
n_positive, n_negative = 2000, 2000
#生成正样本, 小圆环分布
r_p = 5.0 + torch.normal(0.0, 1.0, size=[n_positive, 1])
theta_p = 2 * np.pi * torch.rand([n_positive, 1])
Xp = torch.cat([r_p * torch.cos(theta_p), r_p * torch.sin(theta_p)], axis=1)
Yp = torch.ones_like(r_p)
#生成负样本, 大圆环分布
r_n = 8.0 + torch.normal(0.0, 1.0, size=[n_negative, 1])
theta_n = 2 * np.pi * torch.rand([n_negative, 1])
Xn = torch.cat([r_n * torch.cos(theta_n), r_n * torch.sin(theta_n)], axis=1)
Yn = torch.zeros_like(r_n)
#汇总样本
X = torch.cat([Xp, Xn], axis=0)
Y = torch.cat([Yp, Yn], axis=0)

# %%
# 预览
fig = go.Figure()
trace1 = go.Scatter(x=Xp[:, 0], y=Xp[:, 1], mode='markers', name='p')
trace2 = go.Scatter(x=Xn[:, 0], y=Xn[:, 1], mode='markers', name='n')
fig.add_trace(trace1)
fig.add_trace(trace2)
fig.update_layout(
    autosize=False,
    width=500,
    height=500,
    margin=dict(
        l=10,
        r=10,
        b=100,
        t=100,
        pad=3
    ),
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="867e7108-e68f-4cae-8851-a8ff50c85e5a" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("867e7108-e68f-4cae-8851-a8ff50c85e5a")) {
#                     Plotly.newPlot(
#                         '867e7108-e68f-4cae-8851-a8ff50c85e5a',
#                         [{"mode": "markers", "name": "p", "type": "scatter", "x": [-2.1194851398468018, 3.2329697608947754, -4.681107997894287, -2.314868211746216, 5.133705139160156, 5.134432792663574, -4.356714248657227, -2.9064979553222656, 2.8890202045440674, -3.2215917110443115, 5.277908802032471, -3.8960695266723633, -4.648928642272949, 1.7677452564239502, 1.7337058782577515, -1.5446408987045288, -4.097077369689941, -4.79642391204834, -4.0044074058532715, 0.8623596429824829, 2.7586095333099365, -1.0269465446472168, -0.004597282502800226, 0.4848048686981201, 6.036131381988525, -3.3621559143066406, -2.1103432178497314, 4.7220072746276855, 4.495914936065674, -4.0466437339782715, -4.563859939575195, -0.9033561944961548, 3.3385682106018066, -2.414660930633545, 2.1183223724365234, -3.29121470451355, -4.505882740020752, -3.6100873947143555, -4.040658473968506, -5.945110321044922, 4.38177490234375, -3.134854793548584, -4.267256259918213, 1.9580262899398804, -2.4280331134796143, 0.7302055358886719, 0.49315115809440613, 1.4673291444778442, -0.0908312201499939, -0.8699893355369568, -4.923549652099609, 5.654021263122559, -0.3759736120700836, -3.9033758640289307, 2.689650535583496, -3.815972328186035, 4.282431602478027, -4.902148246765137, -3.9355924129486084, -3.2595949172973633, 3.984980821609497, -4.3196892738342285, 3.0031394958496094, 0.14710241556167603, -2.371992349624634, 6.122875213623047, -2.546847105026245, 1.2743388414382935, -2.8566954135894775, -5.761629581451416, 2.644456148147583, -4.1492018699646, -3.379303455352783, 4.916653156280518, 4.999711513519287, 2.5646297931671143, -3.8606812953948975, -3.2083704471588135, -1.5267904996871948, 5.887515068054199, 4.1913676261901855, -1.8213801383972168, 5.848316192626953, -4.362675189971924, 2.7994511127471924, 4.864782810211182, -3.286951780319214, -3.8794963359832764, -4.942736625671387, 1.7507312297821045, -3.6729342937469482, 2.7008066177368164, -3.5332274436950684, -3.1935133934020996, -0.04584113135933876, 5.655862331390381, -2.402696132659912, 3.1116511821746826, -3.1771304607391357, 3.822439670562744, -5.268099784851074, 4.611567974090576, 0.21126492321491241, -2.1731977462768555, -0.8670925498008728, -1.306103229522705, -5.360928535461426, 3.2483489513397217, 4.930513858795166, 1.4629831314086914, 1.4478579759597778, -4.786472320556641, -2.882791519165039, 3.8576416969299316, -0.8499711751937866, 5.815897464752197, 0.5868533253669739, -3.6069154739379883, 4.591557025909424, 3.61470890045166, -3.9835171699523926, 4.320075988769531, 4.174530982971191, -4.593419075012207, 6.025717258453369, -5.369783401489258, -3.2795605659484863, -1.1898548603057861, -3.8211898803710938, 0.5636017322540283, 4.022273540496826, 6.245986461639404, -1.6977096796035767, -3.4137215614318848, 1.1672996282577515, -3.0318686962127686, -3.7885117530822754, 2.572864055633545, 4.921384334564209, -3.9274070262908936, 5.586676597595215, 5.829931735992432, -2.634273052215576, 2.3863706588745117, 4.046892166137695, 3.0245554447174072, 2.0676426887512207, -2.898646116256714, -3.183683156967163, 3.820420742034912, 4.9031877517700195, -2.5066606998443604, -1.881675124168396, -3.1214358806610107, 5.5080084800720215, -5.028326511383057, -4.535302639007568, -4.819333553314209, 4.439329624176025, 5.315240383148193, 0.39705318212509155, 1.8917585611343384, -3.8069632053375244, -2.349496841430664, 5.916879653930664, -2.4082038402557373, 1.4284549951553345, 2.5202975273132324, -4.640813827514648, 4.497420787811279, 2.6417105197906494, -4.506298542022705, -1.7655936479568481, -3.642038345336914, 2.5340137481689453, 5.627501487731934, -6.037936210632324, 3.637706995010376, 5.902146816253662, -4.906769275665283, 2.404109001159668, -0.37933745980262756, -3.464963436126709, 4.641129016876221, -0.5243467092514038, -2.9969356060028076, -0.8952131271362305, 2.4854183197021484, -1.2246044874191284, -5.014098167419434, 1.8642865419387817, -2.612170457839966, -4.72371768951416, -3.010326862335205, -4.131537914276123, 5.231 ...

# %% [markdown]
# ## 低阶API

# %%
# 构建数据迭代器
def data_iter(features: torch.Tensor, labels, batch_size=8):
    num_exampls = len(features)
    idx = list(range(num_exampls))
    np.random.shuffle(idx)
    for i in range(0, num_exampls, batch_size):
        new_idx = torch.LongTensor(idx[i:min(i + batch_size, num_exampls)])
        yield features.index_select(0, new_idx), labels.index_select(0, new_idx)

(features, labels) = next(data_iter(X, Y))
print('features: ', features)
print('labels: ', labels)
# Out:
# features:  tensor([[ 0.0100,  6.9156],
#         [ 5.3783, -1.6352],
#         [-4.7164, -2.2320],
#         [ 2.7553, -1.5370],
#         [ 4.3743, -5.0449],
#         [-7.6252, -3.2998],
#         [ 6.8307, -6.3168],
#         [-1.5446, -5.2486]])
# labels:  tensor([[0.],
#         [1.],
#         [1.],
#         [1.],
#         [0.],
#         [0.],
#         [0.],
#         [1.]])

# %%
# 定义模型
class DNNModel(nn.Module):
    def __init__(self):
        super(DNNModel, self).__init__()
        self.w1 = nn.Parameter(torch.randn(2, 4))
        self.b1 = nn.Parameter(torch.zeros(1, 4))
        self.w2 = nn.Parameter(torch.randn(4, 8))
        self.b2 = nn.Parameter(torch.zeros(1, 8))
        self.w3 = nn.Parameter(torch.randn(8, 1))
        self.b3 = nn.Parameter(torch.zeros(1, 1))

    def forward(self, x):
        x = torch.relu(x@self.w1 + self.b1)
        x = torch.relu(x@self.w2 + self.b2)
        y = torch.sigmoid(x@self.w3 + self.b3)
        return y

    # 二元交叉熵
    def loss_func(self, y_pred, y_true):
        # 避免log(0) 错误
        eps = 1e-7
        y_pred = torch.clamp(y_pred, eps, 1.0-eps)
        bce = -y_true * torch.log(y_pred) - (1 - y_true) * torch.log(1 - y_pred)
        return torch.mean(bce)

    def metric_func(self, y_pred, y_true):
        y_pred = torch.where(y_pred > 0.5, torch.ones_like(y_pred, dtype=torch.float32),
                             torch.zeros_like(y_pred, dtype=torch.float32))
        acc = torch.mean(1 - torch.abs(y_true - y_pred))
        return acc


model = DNNModel()

# %%
# 测试结构
batch_size = 10
(features, labels) = next(data_iter(X, Y, batch_size))
predictions = model(features)

loss = model.loss_func(labels, predictions)
metric = model.metric_func(labels, predictions)
print("init loss:", loss.item())
print("init metric:", metric.item())
# Out:
# init loss: 9.562487602233887
# init metric: 0.4001845717430115

# %%
def train_step(model, features, labels):
    # 正向
    predictions = model.forward(features)
    loss = model.loss_func(predictions, labels)
    metric = model.metric_func(predictions, labels)

    # 反向
    loss.backward()

    # 更新参数
    for param in model.parameters():
        param.data = (param.data - 0.01 * param.grad.data)

    # 梯度清零
    model.zero_grad()
    return loss.item(), metric.item()

# (features, labels) = next(data_iter(X, Y, batch_size))
# loss, metric = train_step(model, features, labels)
# print(loss, metric)


def train_model(model, epochs):
    for epoch in range(1, epochs+1):
        loss_list, metric_list = [], []
        for features, labels in data_iter(X, Y, batch_size):
            lossi, metrici = train_step(model, features, labels)
            loss_list.append(lossi)
            metric_list.append(metrici)
        loss = np.mean(loss_list)
        metric = np.mean(metric_list)

        if epoch % 100 == 0:
            print('epoch={} loss={} metric={} '.format(epoch, loss, metric))


train_model(model, epochs=500)
# Out:
# epoch=100 loss=0.18610517101595178 metric=0.9294999922811985
# epoch=200 loss=0.18402794773457573 metric=0.9252499924600124
# epoch=300 loss=0.1774154716054909 metric=0.9284999933838844
# epoch=400 loss=0.17851714089163578 metric=0.9292499920725823
# epoch=500 loss=0.17628757865400985 metric=0.928999992609024

# %%
# 预测
# X_pred = torch.squeeze(model.forward(X))
Xp_pred = X[torch.squeeze(model.forward(X)>=0.5)]
Xn_pred = X[torch.squeeze(model.forward(X)<0.5)]
Xp_pred
# Out:
# tensor([[-2.1195,  4.4397],
#         [ 3.2330, -5.0898],
#         [-4.6811,  2.3082],
#         ...,
#         [-3.8134, -5.3091],
#         [-0.3192, -6.3915],
#         [-1.2381, -6.3085]])

# %%
# 预览
from plotly.subplots import make_subplots

fig = go.Figure()
trace_Xp = go.Scatter(x=Xp[:, 0], y=Xp[:, 1], mode='markers', name='p')
trace_Xn = go.Scatter(x=Xn[:, 0], y=Xn[:, 1], mode='markers', name='n')

trace_Xp_pred = go.Scatter(x=Xp_pred[:, 0], y=Xp_pred[:, 1], mode='markers', name='Xp_pre')
trace_Xn_pred = go.Scatter(x=Xn_pred[:, 0], y=Xn_pred[:, 1], mode='markers', name='Xn_pre')

# fig.add_trace(trace_Xp)
# fig.add_trace(trace_Xn)

fig = make_subplots(rows=1,  # 将画布分为两行
            cols=2,  # 将画布分为两列
            subplot_titles=['y_true','y_pred'],# 子图的标题
            x_title="x",
            y_title="y"
            )

fig.add_trace(trace_Xp,1,1)
fig.add_trace(trace_Xn,1,1)
fig.add_trace(trace_Xp_pred,1,2)
fig.add_trace(trace_Xn_pred,1,2)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ffe368af-e3c0-44a4-a101-f17917b1625b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ffe368af-e3c0-44a4-a101-f17917b1625b")) {
#                     Plotly.newPlot(
#                         'ffe368af-e3c0-44a4-a101-f17917b1625b',
#                         [{"mode": "markers", "name": "p", "type": "scatter", "x": [-2.1194851398468018, 3.2329697608947754, -4.681107997894287, -2.314868211746216, 5.133705139160156, 5.134432792663574, -4.356714248657227, -2.9064979553222656, 2.8890202045440674, -3.2215917110443115, 5.277908802032471, -3.8960695266723633, -4.648928642272949, 1.7677452564239502, 1.7337058782577515, -1.5446408987045288, -4.097077369689941, -4.79642391204834, -4.0044074058532715, 0.8623596429824829, 2.7586095333099365, -1.0269465446472168, -0.004597282502800226, 0.4848048686981201, 6.036131381988525, -3.3621559143066406, -2.1103432178497314, 4.7220072746276855, 4.495914936065674, -4.0466437339782715, -4.563859939575195, -0.9033561944961548, 3.3385682106018066, -2.414660930633545, 2.1183223724365234, -3.29121470451355, -4.505882740020752, -3.6100873947143555, -4.040658473968506, -5.945110321044922, 4.38177490234375, -3.134854793548584, -4.267256259918213, 1.9580262899398804, -2.4280331134796143, 0.7302055358886719, 0.49315115809440613, 1.4673291444778442, -0.0908312201499939, -0.8699893355369568, -4.923549652099609, 5.654021263122559, -0.3759736120700836, -3.9033758640289307, 2.689650535583496, -3.815972328186035, 4.282431602478027, -4.902148246765137, -3.9355924129486084, -3.2595949172973633, 3.984980821609497, -4.3196892738342285, 3.0031394958496094, 0.14710241556167603, -2.371992349624634, 6.122875213623047, -2.546847105026245, 1.2743388414382935, -2.8566954135894775, -5.761629581451416, 2.644456148147583, -4.1492018699646, -3.379303455352783, 4.916653156280518, 4.999711513519287, 2.5646297931671143, -3.8606812953948975, -3.2083704471588135, -1.5267904996871948, 5.887515068054199, 4.1913676261901855, -1.8213801383972168, 5.848316192626953, -4.362675189971924, 2.7994511127471924, 4.864782810211182, -3.286951780319214, -3.8794963359832764, -4.942736625671387, 1.7507312297821045, -3.6729342937469482, 2.7008066177368164, -3.5332274436950684, -3.1935133934020996, -0.04584113135933876, 5.655862331390381, -2.402696132659912, 3.1116511821746826, -3.1771304607391357, 3.822439670562744, -5.268099784851074, 4.611567974090576, 0.21126492321491241, -2.1731977462768555, -0.8670925498008728, -1.306103229522705, -5.360928535461426, 3.2483489513397217, 4.930513858795166, 1.4629831314086914, 1.4478579759597778, -4.786472320556641, -2.882791519165039, 3.8576416969299316, -0.8499711751937866, 5.815897464752197, 0.5868533253669739, -3.6069154739379883, 4.591557025909424, 3.61470890045166, -3.9835171699523926, 4.320075988769531, 4.174530982971191, -4.593419075012207, 6.025717258453369, -5.369783401489258, -3.2795605659484863, -1.1898548603057861, -3.8211898803710938, 0.5636017322540283, 4.022273540496826, 6.245986461639404, -1.6977096796035767, -3.4137215614318848, 1.1672996282577515, -3.0318686962127686, -3.7885117530822754, 2.572864055633545, 4.921384334564209, -3.9274070262908936, 5.586676597595215, 5.829931735992432, -2.634273052215576, 2.3863706588745117, 4.046892166137695, 3.0245554447174072, 2.0676426887512207, -2.898646116256714, -3.183683156967163, 3.820420742034912, 4.9031877517700195, -2.5066606998443604, -1.881675124168396, -3.1214358806610107, 5.5080084800720215, -5.028326511383057, -4.535302639007568, -4.819333553314209, 4.439329624176025, 5.315240383148193, 0.39705318212509155, 1.8917585611343384, -3.8069632053375244, -2.349496841430664, 5.916879653930664, -2.4082038402557373, 1.4284549951553345, 2.5202975273132324, -4.640813827514648, 4.497420787811279, 2.6417105197906494, -4.506298542022705, -1.7655936479568481, -3.642038345336914, 2.5340137481689453, 5.627501487731934, -6.037936210632324, 3.637706995010376, 5.902146816253662, -4.906769275665283, 2.404109001159668, -0.37933745980262756, -3.464963436126709, 4.641129016876221, -0.5243467092514038, -2.9969356060028076, -0.8952131271362305, 2.4854183197021484, -1.2246044874191284, -5.014098167419434, 1.8642865419387817, -2.612170457839966, -4.72371768951416, -3.010326862335205, -4.131537914276123, 5.231 ...

# %% [markdown]
# ## 中阶API

# %%
print(X.shape)
print(Y.shape)
# Out:
# torch.Size([4000, 2])
# torch.Size([4000, 1])

# %%
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torch.nn import functional as F
ds = TensorDataset(X, Y)
dl = DataLoader(ds,batch_size=10,num_workers=2,shuffle=True)

# %%
class DNNModel(nn.Module):
    def __init__(self):
        super(DNNModel,self ).__init__()
        self.fc1 = nn.Linear(2,5)
        self.fc2 = nn.Linear(5,9)
        self.fc3 = nn.Linear(9,1)
    
    def forward(self,x):
        x=F.relu(self.fc1(x))
        x=F.relu(self.fc2(x))
        x=nn.Sigmoid()(self.fc3(x))
        return x
    
    def loss_func(self, y_pred, y_true):
        return nn.BCELoss()(y_pred, y_true)

    def metric_func(self,y_pred,y_true):
        y_pred = torch.where(y_pred>0.5, torch.ones_like(y_pred,dtype=torch.float32), torch.zeros_like(y_pred,dtype=torch.float32))
        acc = torch.mean(1-torch.abs(y_true-y_pred))
        return acc
    
    @property
    def optimizer(self):
        return torch.optim.Adam(self.parameters(), lr=0.001)

model = DNNModel()

# %%
# 测试模型
(features, labels) = next(iter(dl))
predictions = model(features)

loss = model.loss_func(predictions, labels)
metric = model.metric_func(predictions, labels)

print('loss=',loss.item())
print('metric=',metric.item())
# Out:
# loss= 0.8797765970230103
# metric= 0.20000000298023224

# %%
def train_step(model, features, labels):
    # 正向
    predictions = model(features)
    loss = model.loss_func(predictions, labels)
    metric = model.metric_func(predictions, labels)

    # 反向
    loss.backward()

    # 参数更新
    model.optimizer.step()
    model.optimizer.zero_grad()

    return loss.item(), metric.item()

features,labels = next(iter(dl))
train_step(model,features,labels)
# Out:
# (0.7293962240219116, 0.30000001192092896)

# %%
def train_model(model, epochs):
    for epoch in range(1, epochs+1):
        list_loss,list_metric=[],[]
        for features, labels in dl:
            lossi,metrici = train_step(model, features, labels)
            list_loss.append(lossi)
            list_metric.append(metrici)
        loss = np.mean(list_loss)
        metric = np.mean(list_metric)

        if epoch % 100 == 0:
            print('epoch={} | loss={} | metric={}'.format(epoch,loss,metric))
train_model(model, 500)
# Out:
# epoch=100 | loss=0.24013393647928752 | metric=0.9199999916553497
# epoch=200 | loss=0.2614943907559609 | metric=0.9234999921917916
# epoch=300 | loss=0.33852576003051127 | metric=0.9229999913275242
# epoch=400 | loss=0.3222889948804772 | metric=0.9242499923706055
# epoch=500 | loss=0.29889976761380693 | metric=0.924999992698431

# %%
# 预测
# X_pred = torch.squeeze(model.forward(X))
Xp_pred = X[torch.squeeze(model.forward(X)>=0.5)]
Xn_pred = X[torch.squeeze(model.forward(X)<0.5)]
Xp_pred
# Out:
# tensor([[-2.1195,  4.4397],
#         [ 3.2330, -5.0898],
#         [-4.6811,  2.3082],
#         ...,
#         [-5.1976, -3.7398],
#         [-3.8134, -5.3091],
#         [-0.3192, -6.3915]])

# %%
# 预览
from plotly.subplots import make_subplots

fig = go.Figure()

trace_Xp = go.Scatter(x=Xp[:, 0], y=Xp[:, 1], mode='markers', name='p')
trace_Xn = go.Scatter(x=Xn[:, 0], y=Xn[:, 1], mode='markers', name='n')
trace_Xp_pred = go.Scatter(x=Xp_pred[:, 0], y=Xp_pred[:, 1], mode='markers', name='p_pre')
trace_Xn_pred = go.Scatter(x=Xn_pred[:, 0], y=Xn_pred[:, 1], mode='markers', name='n_pre')


fig = make_subplots(rows=1,  # 将画布分为两行
            cols=2,  # 将画布分为两列
            subplot_titles=['y_true','y_pred'],# 子图的标题
            x_title="x",
            y_title="y"
            )

fig.add_trace(trace_Xp,1,1)
fig.add_trace(trace_Xn,1,1)
fig.add_trace(trace_Xp_pred,1,2)
fig.add_trace(trace_Xn_pred,1,2)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="82776597-749b-4933-82e1-0d631d420dc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("82776597-749b-4933-82e1-0d631d420dc5")) {
#                     Plotly.newPlot(
#                         '82776597-749b-4933-82e1-0d631d420dc5',
#                         [{"mode": "markers", "name": "p", "type": "scatter", "x": [-2.1194851398468018, 3.2329697608947754, -4.681107997894287, -2.314868211746216, 5.133705139160156, 5.134432792663574, -4.356714248657227, -2.9064979553222656, 2.8890202045440674, -3.2215917110443115, 5.277908802032471, -3.8960695266723633, -4.648928642272949, 1.7677452564239502, 1.7337058782577515, -1.5446408987045288, -4.097077369689941, -4.79642391204834, -4.0044074058532715, 0.8623596429824829, 2.7586095333099365, -1.0269465446472168, -0.004597282502800226, 0.4848048686981201, 6.036131381988525, -3.3621559143066406, -2.1103432178497314, 4.7220072746276855, 4.495914936065674, -4.0466437339782715, -4.563859939575195, -0.9033561944961548, 3.3385682106018066, -2.414660930633545, 2.1183223724365234, -3.29121470451355, -4.505882740020752, -3.6100873947143555, -4.040658473968506, -5.945110321044922, 4.38177490234375, -3.134854793548584, -4.267256259918213, 1.9580262899398804, -2.4280331134796143, 0.7302055358886719, 0.49315115809440613, 1.4673291444778442, -0.0908312201499939, -0.8699893355369568, -4.923549652099609, 5.654021263122559, -0.3759736120700836, -3.9033758640289307, 2.689650535583496, -3.815972328186035, 4.282431602478027, -4.902148246765137, -3.9355924129486084, -3.2595949172973633, 3.984980821609497, -4.3196892738342285, 3.0031394958496094, 0.14710241556167603, -2.371992349624634, 6.122875213623047, -2.546847105026245, 1.2743388414382935, -2.8566954135894775, -5.761629581451416, 2.644456148147583, -4.1492018699646, -3.379303455352783, 4.916653156280518, 4.999711513519287, 2.5646297931671143, -3.8606812953948975, -3.2083704471588135, -1.5267904996871948, 5.887515068054199, 4.1913676261901855, -1.8213801383972168, 5.848316192626953, -4.362675189971924, 2.7994511127471924, 4.864782810211182, -3.286951780319214, -3.8794963359832764, -4.942736625671387, 1.7507312297821045, -3.6729342937469482, 2.7008066177368164, -3.5332274436950684, -3.1935133934020996, -0.04584113135933876, 5.655862331390381, -2.402696132659912, 3.1116511821746826, -3.1771304607391357, 3.822439670562744, -5.268099784851074, 4.611567974090576, 0.21126492321491241, -2.1731977462768555, -0.8670925498008728, -1.306103229522705, -5.360928535461426, 3.2483489513397217, 4.930513858795166, 1.4629831314086914, 1.4478579759597778, -4.786472320556641, -2.882791519165039, 3.8576416969299316, -0.8499711751937866, 5.815897464752197, 0.5868533253669739, -3.6069154739379883, 4.591557025909424, 3.61470890045166, -3.9835171699523926, 4.320075988769531, 4.174530982971191, -4.593419075012207, 6.025717258453369, -5.369783401489258, -3.2795605659484863, -1.1898548603057861, -3.8211898803710938, 0.5636017322540283, 4.022273540496826, 6.245986461639404, -1.6977096796035767, -3.4137215614318848, 1.1672996282577515, -3.0318686962127686, -3.7885117530822754, 2.572864055633545, 4.921384334564209, -3.9274070262908936, 5.586676597595215, 5.829931735992432, -2.634273052215576, 2.3863706588745117, 4.046892166137695, 3.0245554447174072, 2.0676426887512207, -2.898646116256714, -3.183683156967163, 3.820420742034912, 4.9031877517700195, -2.5066606998443604, -1.881675124168396, -3.1214358806610107, 5.5080084800720215, -5.028326511383057, -4.535302639007568, -4.819333553314209, 4.439329624176025, 5.315240383148193, 0.39705318212509155, 1.8917585611343384, -3.8069632053375244, -2.349496841430664, 5.916879653930664, -2.4082038402557373, 1.4284549951553345, 2.5202975273132324, -4.640813827514648, 4.497420787811279, 2.6417105197906494, -4.506298542022705, -1.7655936479568481, -3.642038345336914, 2.5340137481689453, 5.627501487731934, -6.037936210632324, 3.637706995010376, 5.902146816253662, -4.906769275665283, 2.404109001159668, -0.37933745980262756, -3.464963436126709, 4.641129016876221, -0.5243467092514038, -2.9969356060028076, -0.8952131271362305, 2.4854183197021484, -1.2246044874191284, -5.014098167419434, 1.8642865419387817, -2.612170457839966, -4.72371768951416, -3.010326862335205, -4.131537914276123, 5.231 ...

# %% [markdown]
# # 高阶API

# %%
print(X.shape)
print(Y.shape)
# Out:
# torch.Size([4000, 2])
# torch.Size([4000, 1])

# %%
ds = TensorDataset(X,Y)
split_ration = 0.7
ds_train,ds_valid = torch.utils.data.random_split(ds,[int(len(ds)*split_ration),len(ds)-int(len(ds)*split_ration)])
dl_train = DataLoader(ds_train,batch_size = 100,shuffle=True,num_workers=2)
dl_valid = DataLoader(ds_valid,batch_size = 100,num_workers=2)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.fc1 = nn.Linear(2,4)
        self.fc2 = nn.Linear(4,8)
        self.fc3 = nn.Linear(8,1)
    
    def forward(self,x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        y = nn.Sigmoid()(self.fc3(x))
        return y

# %%
# !pip install torchkeras
import torchkeras

model = torchkeras.Model(Net())
model.summary(input_shape =(2,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 4]              12
#             Linear-2                    [-1, 8]              40
#             Linear-3                    [-1, 1]               9
# ================================================================
# Total params: 61
# Trainable params: 61
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.000008
# Forward/backward pass size (MB): 0.000099
# Params size (MB): 0.000233
# Estimated Total Size (MB): 0.000340
# ----------------------------------------------------------------

# %%
def accuracy(y_pred, y_true):
    y_pred = torch.where(y_pred>0.5, torch.ones_like(y_pred,dtype=torch.float32),torch.zeros_like(y_pred,dtype=torch.float32,))
    acc = torch.mean(1-torch.abs(y_pred-y_true))
    return acc

model.compile(loss_func=nn.BCELoss(),optimizer=torch.optim.Adam(model.parameters(), lr=0.01), metrics_dict={'accuracy':accuracy})
dfhistory = model.fit(100,dl_train=dl_train,dl_val=dl_valid,log_step_freq=20)
# Out:
# Start Training ...
#
# ================================================================================2021-12-01 03:09:44
# {'step': 20, 'loss': 0.166, 'accuracy': 0.934}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   1   | 0.173 |  0.932   |  0.205   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:44
# {'step': 20, 'loss': 0.174, 'accuracy': 0.932}
#
#  +-------+------+----------+----------+--------------+
# | epoch | loss | accuracy | val_loss | val_accuracy |
# +-------+------+----------+----------+--------------+
# |   2   | 0.17 |  0.933   |  0.204   |    0.924     |
# +-------+------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:44
# {'step': 20, 'loss': 0.167, 'accuracy': 0.934}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   3   | 0.169 |  0.933   |  0.213   |    0.916     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:44
# {'step': 20, 'loss': 0.178, 'accuracy': 0.93}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   4   | 0.173 |  0.929   |  0.206   |    0.922     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:45
# {'step': 20, 'loss': 0.173, 'accuracy': 0.932}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   5   | 0.171 |  0.933   |  0.214   |    0.918     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:45
# {'step': 20, 'loss': 0.158, 'accuracy': 0.936}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   6   | 0.164 |  0.933   |  0.201   |    0.926     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:45
# {'step': 20, 'loss': 0.171, 'accuracy': 0.927}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   7   | 0.167 |  0.932   |  0.205   |    0.922     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:46
# {'step': 20, 'loss': 0.17, 'accuracy': 0.934}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   8   | 0.169 |  0.934   |  0.208   |     0.92     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:46
# {'step': 20, 'loss': 0.166, 'accuracy': 0.932}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   9   | 0.168 |  0.931   |  0.204   |    0.921     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:46
# {'step': 20, 'loss': 0.156, 'accuracy': 0.938}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   10  | 0.164 |  0.935   |  0.207   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:47
# {'step': 20, 'loss': 0.159, 'accuracy': 0.933}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   11  | 0.166 |  0.933   |  0.206   |    0.919     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:47
# {'step': 20, 'loss': 0.167, 'accuracy': 0.93}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   12  | 0.168 |   0.93   |  0.218   |    0.914     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:47
# {'step': 20, 'loss': 0.162, 'accuracy': 0.933}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   13  | 0.168 |  0.929   |  0.205   |     0.92     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:48
# {'step': 20, 'loss': 0.158, 'accuracy': 0.94}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   14  | 0.165 |  0.933   |  0.204   |    0.924     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:48
# {'step': 20, 'loss': 0.167, 'accuracy': 0.934}
#
#  +-------+------+----------+----------+--------------+
# | epoch | loss | accuracy | val_loss | val_accuracy |
# +-------+------+----------+----------+--------------+
# |   15  | 0.17 |  0.932   |  0.209   |    0.918     |
# +-------+------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:48
# {'step': 20, 'loss': 0.17, 'accuracy': 0.926}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   16  | 0.168 |  0.929   |  0.202   |    0.924     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:49
# {'step': 20, 'loss': 0.169, 'accuracy': 0.931}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   17  | 0.166 |  0.933   |  0.214   |    0.916     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:49
# {'step': 20, 'loss': 0.168, 'accuracy': 0.933}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   18  | 0.167 |  0.936   |  0.206   |    0.922     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:49
# {'step': 20, 'loss': 0.167, 'accuracy': 0.934}
#
#  +-------+------+----------+----------+--------------+
# | epoch | loss | accuracy | val_loss | val_accuracy |
# +-------+------+----------+----------+--------------+
# |   19  | 0.17 |  0.931   |  0.205   |    0.923     |
# +-------+------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:50
# {'step': 20, 'loss': 0.176, 'accuracy': 0.931}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   20  | 0.169 |  0.936   |  0.204   |    0.924     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:50
# {'step': 20, 'loss': 0.168, 'accuracy': 0.932}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   21  | 0.168 |  0.932   |   0.21   |    0.918     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:50
# {'step': 20, 'loss': 0.169, 'accuracy': 0.936}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   22  | 0.166 |  0.934   |  0.207   |    0.924     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:51
# {'step': 20, 'loss': 0.164, 'accuracy': 0.936}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   23  | 0.165 |  0.936   |  0.206   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:51
# {'step': 20, 'loss': 0.173, 'accuracy': 0.933}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   24  | 0.169 |  0.933   |  0.214   |    0.918     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:51
# {'step': 20, 'loss': 0.171, 'accuracy': 0.93}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   25  | 0.172 |  0.932   |  0.215   |    0.918     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:52
# {'step': 20, 'loss': 0.17, 'accuracy': 0.934}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   26  | 0.171 |  0.932   |  0.206   |    0.924     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:52
# {'step': 20, 'loss': 0.163, 'accuracy': 0.932}
#
#  +-------+------+----------+----------+--------------+
# | epoch | loss | accuracy | val_loss | val_accuracy |
# +-------+------+----------+----------+--------------+
# |   27  | 0.17 |  0.931   |  0.206   |    0.922     |
# +-------+------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:52
# {'step': 20, 'loss': 0.169, 'accuracy': 0.932}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   28  | 0.168 |  0.931   |  0.207   |    0.922     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:53
# {'step': 20, 'loss': 0.172, 'accuracy': 0.933}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   29  | 0.169 |  0.934   |  0.209   |     0.92     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:53
# {'step': 20, 'loss': 0.17, 'accuracy': 0.93}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   30  | 0.169 |  0.932   |  0.208   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:53
# {'step': 20, 'loss': 0.169, 'accuracy': 0.933}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   31  | 0.167 |  0.934   |   0.21   |    0.919     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:54
# {'step': 20, 'loss': 0.171, 'accuracy': 0.931}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   32  | 0.167 |  0.931   |  0.205   |    0.922     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:54
# {'step': 20, 'loss': 0.181, 'accuracy': 0.927}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   33  | 0.167 |  0.931   |  0.203   |    0.927     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:54
# {'step': 20, 'loss': 0.156, 'accuracy': 0.938}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   34  | 0.166 |  0.933   |  0.206   |    0.919     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:55
# {'step': 20, 'loss': 0.161, 'accuracy': 0.934}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   35  | 0.167 |  0.932   |  0.207   |    0.922     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:55
# {'step': 20, 'loss': 0.168, 'accuracy': 0.932}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   36  | 0.168 |  0.932   |  0.203   |    0.924     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:55
# {'step': 20, 'loss': 0.165, 'accuracy': 0.939}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   37  | 0.169 |  0.934   |  0.221   |    0.916     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:56
# {'step': 20, 'loss': 0.171, 'accuracy': 0.93}
#
#  +-------+------+----------+----------+--------------+
# | epoch | loss | accuracy | val_loss | val_accuracy |
# +-------+------+----------+----------+--------------+
# |   38  | 0.17 |  0.929   |  0.233   |    0.903     |
# +-------+------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:56
# {'step': 20, 'loss': 0.186, 'accuracy': 0.926}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   39  | 0.178 |  0.929   |  0.204   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:56
# {'step': 20, 'loss': 0.166, 'accuracy': 0.932}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   40  | 0.168 |  0.932   |  0.213   |    0.916     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:56
# {'step': 20, 'loss': 0.171, 'accuracy': 0.929}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   41  | 0.167 |  0.933   |  0.203   |    0.925     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:57
# {'step': 20, 'loss': 0.176, 'accuracy': 0.928}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   42  | 0.169 |  0.929   |  0.208   |    0.924     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:57
# {'step': 20, 'loss': 0.171, 'accuracy': 0.931}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   43  | 0.166 |  0.932   |  0.209   |     0.92     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:57
# {'step': 20, 'loss': 0.163, 'accuracy': 0.932}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   44  | 0.169 |  0.931   |  0.213   |     0.92     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:58
# {'step': 20, 'loss': 0.175, 'accuracy': 0.929}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   45  | 0.174 |  0.932   |  0.207   |    0.921     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:58
# {'step': 20, 'loss': 0.173, 'accuracy': 0.93}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   46  | 0.171 |  0.931   |  0.205   |    0.921     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:58
# {'step': 20, 'loss': 0.173, 'accuracy': 0.929}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   47  | 0.168 |  0.933   |  0.206   |    0.921     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:59
# {'step': 20, 'loss': 0.157, 'accuracy': 0.935}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   48  | 0.163 |  0.933   |  0.207   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:59
# {'step': 20, 'loss': 0.175, 'accuracy': 0.93}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   49  | 0.166 |  0.934   |  0.213   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:09:59
# {'step': 20, 'loss': 0.172, 'accuracy': 0.933}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   50  | 0.172 |  0.933   |  0.209   |    0.922     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:00
# {'step': 20, 'loss': 0.175, 'accuracy': 0.926}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   51  | 0.168 |   0.93   |  0.208   |    0.918     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:00
# {'step': 20, 'loss': 0.167, 'accuracy': 0.934}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   52  | 0.168 |  0.932   |  0.203   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:00
# {'step': 20, 'loss': 0.166, 'accuracy': 0.934}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   53  | 0.164 |  0.936   |  0.204   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:01
# {'step': 20, 'loss': 0.175, 'accuracy': 0.928}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   54  | 0.168 |   0.93   |  0.202   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:01
# {'step': 20, 'loss': 0.167, 'accuracy': 0.931}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   55  | 0.167 |   0.93   |   0.21   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:01
# {'step': 20, 'loss': 0.168, 'accuracy': 0.938}
#
#  +-------+------+----------+----------+--------------+
# | epoch | loss | accuracy | val_loss | val_accuracy |
# +-------+------+----------+----------+--------------+
# |   56  | 0.17 |  0.935   |  0.205   |    0.921     |
# +-------+------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:02
# {'step': 20, 'loss': 0.15, 'accuracy': 0.939}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   57  | 0.168 |  0.931   |   0.21   |     0.92     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:02
# {'step': 20, 'loss': 0.169, 'accuracy': 0.93}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   58  | 0.169 |  0.931   |  0.218   |    0.916     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:02
# {'step': 20, 'loss': 0.18, 'accuracy': 0.93}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   59  | 0.169 |  0.934   |   0.21   |     0.92     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:03
# {'step': 20, 'loss': 0.171, 'accuracy': 0.931}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   60  | 0.167 |  0.932   |  0.207   |     0.92     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:03
# {'step': 20, 'loss': 0.159, 'accuracy': 0.933}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   61  | 0.165 |  0.932   |  0.205   |    0.922     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:03
# {'step': 20, 'loss': 0.157, 'accuracy': 0.937}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   62  | 0.165 |  0.931   |  0.211   |    0.918     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:04
# {'step': 20, 'loss': 0.162, 'accuracy': 0.934}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   63  | 0.166 |  0.934   |  0.215   |    0.918     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:04
# {'step': 20, 'loss': 0.169, 'accuracy': 0.936}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   64  | 0.167 |  0.934   |  0.203   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:04
# {'step': 20, 'loss': 0.165, 'accuracy': 0.935}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   65  | 0.167 |  0.934   |  0.211   |    0.918     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:05
# {'step': 20, 'loss': 0.172, 'accuracy': 0.932}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   66  | 0.166 |  0.932   |  0.203   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:05
# {'step': 20, 'loss': 0.166, 'accuracy': 0.935}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   67  | 0.169 |  0.935   |  0.224   |    0.912     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:05
# {'step': 20, 'loss': 0.162, 'accuracy': 0.932}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   68  | 0.165 |  0.932   |  0.204   |    0.922     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:06
# {'step': 20, 'loss': 0.163, 'accuracy': 0.938}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   69  | 0.166 |  0.935   |  0.208   |    0.921     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:06
# {'step': 20, 'loss': 0.17, 'accuracy': 0.932}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   70  | 0.167 |  0.931   |  0.219   |    0.912     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:06
# {'step': 20, 'loss': 0.171, 'accuracy': 0.932}
#
#  +-------+------+----------+----------+--------------+
# | epoch | loss | accuracy | val_loss | val_accuracy |
# +-------+------+----------+----------+--------------+
# |   71  | 0.17 |  0.934   |  0.219   |    0.914     |
# +-------+------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:07
# {'step': 20, 'loss': 0.179, 'accuracy': 0.931}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   72  | 0.176 |  0.932   |  0.206   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:07
# {'step': 20, 'loss': 0.173, 'accuracy': 0.927}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   73  | 0.169 |  0.931   |  0.219   |    0.914     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:07
# {'step': 20, 'loss': 0.17, 'accuracy': 0.932}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   74  | 0.169 |  0.934   |  0.215   |    0.919     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:08
# {'step': 20, 'loss': 0.177, 'accuracy': 0.928}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   75  | 0.169 |  0.931   |  0.206   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:08
# {'step': 20, 'loss': 0.166, 'accuracy': 0.933}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   76  | 0.165 |  0.934   |  0.204   |    0.926     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:08
# {'step': 20, 'loss': 0.169, 'accuracy': 0.935}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   77  | 0.167 |  0.935   |  0.202   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:09
# {'step': 20, 'loss': 0.171, 'accuracy': 0.931}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   78  | 0.172 |   0.93   |  0.221   |     0.91     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:09
# {'step': 20, 'loss': 0.175, 'accuracy': 0.933}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   79  | 0.172 |  0.934   |  0.216   |    0.918     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:09
# {'step': 20, 'loss': 0.161, 'accuracy': 0.936}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   80  | 0.165 |  0.935   |  0.206   |    0.922     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:10
# {'step': 20, 'loss': 0.175, 'accuracy': 0.928}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   81  | 0.168 |  0.931   |  0.204   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:10
# {'step': 20, 'loss': 0.156, 'accuracy': 0.938}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   82  | 0.165 |  0.934   |  0.204   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:10
# {'step': 20, 'loss': 0.164, 'accuracy': 0.933}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   83  | 0.167 |  0.931   |  0.202   |    0.924     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:11
# {'step': 20, 'loss': 0.158, 'accuracy': 0.932}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   84  | 0.166 |  0.934   |  0.211   |    0.917     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:11
# {'step': 20, 'loss': 0.169, 'accuracy': 0.93}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   85  | 0.167 |   0.93   |  0.204   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:11
# {'step': 20, 'loss': 0.171, 'accuracy': 0.934}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   86  | 0.168 |  0.933   |   0.21   |    0.917     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:11
# {'step': 20, 'loss': 0.162, 'accuracy': 0.936}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   87  | 0.168 |  0.934   |  0.208   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:12
# {'step': 20, 'loss': 0.175, 'accuracy': 0.925}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   88  | 0.166 |  0.931   |  0.201   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:12
# {'step': 20, 'loss': 0.173, 'accuracy': 0.93}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   89  | 0.165 |  0.931   |  0.209   |    0.922     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:12
# {'step': 20, 'loss': 0.146, 'accuracy': 0.943}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   90  | 0.164 |  0.935   |  0.206   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:13
# {'step': 20, 'loss': 0.176, 'accuracy': 0.928}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   91  | 0.167 |   0.93   |  0.201   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:13
# {'step': 20, 'loss': 0.16, 'accuracy': 0.936}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   92  | 0.167 |  0.933   |  0.208   |    0.924     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:13
# {'step': 20, 'loss': 0.165, 'accuracy': 0.937}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   93  | 0.166 |  0.935   |  0.205   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:14
# {'step': 20, 'loss': 0.174, 'accuracy': 0.93}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   94  | 0.168 |  0.931   |  0.209   |    0.923     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:14
# {'step': 20, 'loss': 0.167, 'accuracy': 0.934}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   95  | 0.166 |  0.933   |  0.208   |    0.921     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:14
# {'step': 20, 'loss': 0.175, 'accuracy': 0.93}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   96  | 0.169 |  0.933   |  0.211   |     0.92     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:15
# {'step': 20, 'loss': 0.176, 'accuracy': 0.932}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   97  | 0.173 |  0.932   |  0.203   |    0.924     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:15
# {'step': 20, 'loss': 0.162, 'accuracy': 0.94}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   98  | 0.168 |  0.937   |  0.204   |    0.924     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:15
# {'step': 20, 'loss': 0.175, 'accuracy': 0.93}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |   99  | 0.168 |  0.931   |  0.206   |    0.925     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:16
# {'step': 20, 'loss': 0.166, 'accuracy': 0.934}
#
#  +-------+-------+----------+----------+--------------+
# | epoch |  loss | accuracy | val_loss | val_accuracy |
# +-------+-------+----------+----------+--------------+
# |  100  | 0.167 |  0.933   |  0.206   |    0.922     |
# +-------+-------+----------+----------+--------------+
#
# ================================================================================2021-12-01 03:10:16
# Finished Training...

# %%
# 预测
# X_pred = torch.squeeze(model.forward(X))
Xp_pred = X[torch.squeeze(model.forward(X)>=0.5)]
Xn_pred = X[torch.squeeze(model.forward(X)<0.5)]
Xp_pred
# Out:
# tensor([[-2.1195,  4.4397],
#         [ 3.2330, -5.0898],
#         [-4.6811,  2.3082],
#         ...,
#         [ 2.8623,  6.0141],
#         [ 5.6765,  2.6894],
#         [-2.6837,  5.4794]])

# %%
# 预览
from plotly.subplots import make_subplots

fig = go.Figure()

trace_Xp = go.Scatter(x=Xp[:, 0], y=Xp[:, 1], mode='markers', name='p')
trace_Xn = go.Scatter(x=Xn[:, 0], y=Xn[:, 1], mode='markers', name='n')
trace_Xp_pred = go.Scatter(x=Xp_pred[:, 0], y=Xp_pred[:, 1], mode='markers', name='p_pre')
trace_Xn_pred = go.Scatter(x=Xn_pred[:, 0], y=Xn_pred[:, 1], mode='markers', name='n_pre')


fig = make_subplots(rows=1,  # 将画布分为两行
            cols=2,  # 将画布分为两列
            subplot_titles=['y_true','y_pred'],# 子图的标题
            x_title="x",
            y_title="y"
            )

fig.add_trace(trace_Xp,1,1)
fig.add_trace(trace_Xn,1,1)
fig.add_trace(trace_Xp_pred,1,2)
fig.add_trace(trace_Xn_pred,1,2)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="975a6a57-089e-4f01-890b-2b23cd5b52a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("975a6a57-089e-4f01-890b-2b23cd5b52a6")) {
#                     Plotly.newPlot(
#                         '975a6a57-089e-4f01-890b-2b23cd5b52a6',
#                         [{"mode": "markers", "name": "p", "type": "scatter", "x": [-2.1194851398468018, 3.2329697608947754, -4.681107997894287, -2.314868211746216, 5.133705139160156, 5.134432792663574, -4.356714248657227, -2.9064979553222656, 2.8890202045440674, -3.2215917110443115, 5.277908802032471, -3.8960695266723633, -4.648928642272949, 1.7677452564239502, 1.7337058782577515, -1.5446408987045288, -4.097077369689941, -4.79642391204834, -4.0044074058532715, 0.8623596429824829, 2.7586095333099365, -1.0269465446472168, -0.004597282502800226, 0.4848048686981201, 6.036131381988525, -3.3621559143066406, -2.1103432178497314, 4.7220072746276855, 4.495914936065674, -4.0466437339782715, -4.563859939575195, -0.9033561944961548, 3.3385682106018066, -2.414660930633545, 2.1183223724365234, -3.29121470451355, -4.505882740020752, -3.6100873947143555, -4.040658473968506, -5.945110321044922, 4.38177490234375, -3.134854793548584, -4.267256259918213, 1.9580262899398804, -2.4280331134796143, 0.7302055358886719, 0.49315115809440613, 1.4673291444778442, -0.0908312201499939, -0.8699893355369568, -4.923549652099609, 5.654021263122559, -0.3759736120700836, -3.9033758640289307, 2.689650535583496, -3.815972328186035, 4.282431602478027, -4.902148246765137, -3.9355924129486084, -3.2595949172973633, 3.984980821609497, -4.3196892738342285, 3.0031394958496094, 0.14710241556167603, -2.371992349624634, 6.122875213623047, -2.546847105026245, 1.2743388414382935, -2.8566954135894775, -5.761629581451416, 2.644456148147583, -4.1492018699646, -3.379303455352783, 4.916653156280518, 4.999711513519287, 2.5646297931671143, -3.8606812953948975, -3.2083704471588135, -1.5267904996871948, 5.887515068054199, 4.1913676261901855, -1.8213801383972168, 5.848316192626953, -4.362675189971924, 2.7994511127471924, 4.864782810211182, -3.286951780319214, -3.8794963359832764, -4.942736625671387, 1.7507312297821045, -3.6729342937469482, 2.7008066177368164, -3.5332274436950684, -3.1935133934020996, -0.04584113135933876, 5.655862331390381, -2.402696132659912, 3.1116511821746826, -3.1771304607391357, 3.822439670562744, -5.268099784851074, 4.611567974090576, 0.21126492321491241, -2.1731977462768555, -0.8670925498008728, -1.306103229522705, -5.360928535461426, 3.2483489513397217, 4.930513858795166, 1.4629831314086914, 1.4478579759597778, -4.786472320556641, -2.882791519165039, 3.8576416969299316, -0.8499711751937866, 5.815897464752197, 0.5868533253669739, -3.6069154739379883, 4.591557025909424, 3.61470890045166, -3.9835171699523926, 4.320075988769531, 4.174530982971191, -4.593419075012207, 6.025717258453369, -5.369783401489258, -3.2795605659484863, -1.1898548603057861, -3.8211898803710938, 0.5636017322540283, 4.022273540496826, 6.245986461639404, -1.6977096796035767, -3.4137215614318848, 1.1672996282577515, -3.0318686962127686, -3.7885117530822754, 2.572864055633545, 4.921384334564209, -3.9274070262908936, 5.586676597595215, 5.829931735992432, -2.634273052215576, 2.3863706588745117, 4.046892166137695, 3.0245554447174072, 2.0676426887512207, -2.898646116256714, -3.183683156967163, 3.820420742034912, 4.9031877517700195, -2.5066606998443604, -1.881675124168396, -3.1214358806610107, 5.5080084800720215, -5.028326511383057, -4.535302639007568, -4.819333553314209, 4.439329624176025, 5.315240383148193, 0.39705318212509155, 1.8917585611343384, -3.8069632053375244, -2.349496841430664, 5.916879653930664, -2.4082038402557373, 1.4284549951553345, 2.5202975273132324, -4.640813827514648, 4.497420787811279, 2.6417105197906494, -4.506298542022705, -1.7655936479568481, -3.642038345336914, 2.5340137481689453, 5.627501487731934, -6.037936210632324, 3.637706995010376, 5.902146816253662, -4.906769275665283, 2.404109001159668, -0.37933745980262756, -3.464963436126709, 4.641129016876221, -0.5243467092514038, -2.9969356060028076, -0.8952131271362305, 2.4854183197021484, -1.2246044874191284, -5.014098167419434, 1.8642865419387817, -2.612170457839966, -4.72371768951416, -3.010326862335205, -4.131537914276123, 5.231 ...

# %%
# 模型评估
dfhistory
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.172960  0.932143  0.205449      0.922500
# 1   0.169799  0.932857  0.203516      0.924167
# 2   0.169343  0.933214  0.212958      0.915833
# 3   0.173387  0.929286  0.206057      0.921667
# 4   0.170659  0.932500  0.214123      0.917500
# ..       ...       ...       ...           ...
# 95  0.168780  0.932857  0.211268      0.920000
# 96  0.173228  0.931786  0.203098      0.924167
# 97  0.167551  0.937143  0.203943      0.924167
# 98  0.167584  0.931429  0.205625      0.925000
# 99  0.167025  0.933214  0.206090      0.921667
#
# [100 rows x 4 columns]

# %%
# 使用模型
model.predict(dl_valid)
# Out:
# tensor([[0.0010],
#         [0.9961],
#         [0.0965],
#         ...,
#         [0.9778],
#         [0.9886],
#         [0.9926]])
